# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("C:\\Users\\ragha\\Downloads\\Dataset .csv")

# %%
display(df.head())
# Out:
#    Restaurant ID         Restaurant Name  Country Code  City  \
# 0        6317637        Le Petit Souffle             6    73
# 1        6304287        Izakaya Kikufuji             6    73
# 2        6300002  Heat - Edsa Shangri-La             6    75
# 3        6318506                    Ooma             6    75
# 4        6314302             Sambo Kojin             6    75
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# ...

# %%
display(df.describe())
# Out:
#        Restaurant ID  Country Code         City    Longitude     Latitude  \
# count   9.542000e+03   9542.000000  9542.000000  9542.000000  9542.000000
# mean    9.043301e+06      1.016139    77.570530    64.274997    25.848532
# std     8.791967e+06      3.415003    22.781307    41.197602    11.010094
# min     5.300000e+01      0.000000     0.000000  -157.948486   -41.330428
# 25%     3.019312e+05      0.000000    78.250000    77.081565    28.478658
# 50%     6.002726e+06      0.000000    87.000000    77.192031    28.570444
# 75%     1.835260e+07      0.000000    87.000000    77.282043    28.642711
# max     1.850065e+07     14.000000   139.000000   174.832089    55.976980
#
#           Cuisines  Average Cost for two  Price range  Aggregate rating  \
# count  9542.000000           9542.000000  9542.000000       9542.000000
# mean    989.163173           1200.326137     1.804968          2.665238
# std     514.326600          16128.743876     0.905563          1.516588
# ...

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9542 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9542 non-null   int64
#  1   Restaurant Name       9542 non-null   object
#  2   Country Code          9542 non-null   int64
#  3   City                  9542 non-null   int64
#  4   Address               9542 non-null   object
#  5   Locality              9542 non-null   object
#  6   Locality Verbose      9542 non-null   object
#  7   Longitude             9542 non-null   float64
#  8   Latitude              9542 non-null   float64
#  9   Cuisines              9542 non-null   int64
#  10  Average Cost for two  9542 non-null   int64
#  11  Currency              9542 non-null   object
#  12  Has Table booking     9542 non-null   object
#  13  Has Online delivery   9542 non-null   object
#  14  Is delivering now     9542 non-null   object
# ...

# %%
categorical_columns = X_train.select_dtypes(include=['object']).columns
numerical_columns = X_train.select_dtypes(exclude=['object']).columns

# Combine train and test data for categorical columns
combined_cat = pd.concat([X_train[categorical_columns], X_test[categorical_columns]], axis=0)

# Create LabelEncoder instance
label_enc = LabelEncoder()

# Convert categorical values to numeric
for column in combined_cat.columns:
    combined_cat[column] = label_enc.fit_transform(combined_cat[column].astype(str))

# Split the combined data back into train and test
X_train[categorical_columns] = combined_cat.iloc[:len(X_train), :]
X_test[categorical_columns] = combined_cat.iloc[len(X_train):, :]

# Combine back numerical columns
X_train = pd.concat([X_train[numerical_columns], X_train[categorical_columns]], axis=1)
X_test = pd.concat([X_test[numerical_columns], X_test[categorical_columns]], axis=1)

# %%
for column in X_train.columns: 
    X_train[column] = pd.to_numeric(X_train[column], errors='coerce') 
for column in X_test.columns: 
    X_test[column] = pd.to_numeric(X_test[column], errors='coerce') 
# Fill any remaining NaN values that were created during conversion 
X_train = X_train.fillna(0)
X_test = X_test.fillna(0)

# %%
lr_model = LinearRegression() 
# Fit the model 
lr_model.fit(X_train, y_train) 
# Make predictions 
y_pred_lr = lr_model.predict(X_test) 
# Evaluate the model 
mse_lr = mean_squared_error(y_test, y_pred_lr) 
r2_lr = r2_score(y_test, y_pred_lr) 
print(f"Linear Regression - MSE: {mse_lr}, R2: {r2_lr}")
# Out:
# Linear Regression - MSE: 1.1157797038116404, R2: 0.512766805961701

# %%
dt_model = DecisionTreeRegressor(random_state=42) 
dt_model.fit(X_train, y_train) 
y_pred_dt = dt_model.predict(X_test) 
mse_dt = mean_squared_error(y_test, y_pred_dt) 
r2_dt = r2_score(y_test, y_pred_dt) 
print(f"Decision Tree - MSE: {mse_dt}, R2: {r2_dt}")
# Out:
# Decision Tree - MSE: 0.054148768988999466, R2: 0.976354581842971

# %%
rf_model = RandomForestRegressor(random_state=42) 
rf_model.fit(X_train, y_train) 
y_pred_rf = rf_model.predict(X_test) 
mse_rf = mean_squared_error(y_test, y_pred_rf) 
r2_rf = r2_score(y_test, y_pred_rf) 
print(f"Random Forest - MSE: {mse_rf}, R2: {r2_rf}")
# Out:
# Random Forest - MSE: 0.027811928758512305, R2: 0.9878552237192664

# %%
print("Model Comparison:")
print(f"Linear Regression - MSE: {mse_lr}, R2: {r2_lr}")
print(f"Decision Tree - MSE: {mse_dt}, R2: {r2_dt}")
print(f"Random Forest - MSE: {mse_rf}, R2: {r2_rf}")
# Out:
# Model Comparison:
# Linear Regression - MSE: 1.1157797038116404, R2: 0.512766805961701
# Decision Tree - MSE: 0.054148768988999466, R2: 0.976354581842971
# Random Forest - MSE: 0.027811928758512305, R2: 0.9878552237192664
